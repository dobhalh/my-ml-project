# %%
from pathlib import Path

import pandas as pd

data_path = Path("data") / "supercars.csv"
df = pd.read_csv(data_path)
df
# Out:
#      Car Model Manufacturer  Year  Top Speed (mph)                 Engine Type
# 0   F8 Tributo      Ferrari  2022              211               V8 Twin-Turbo
# 1  Huracan Evo  Lamborghini  2023              202     V10 Naturally Aspirated
# 2   911 GT3 RS      Porsche  2023              184  Flat-6 Naturally Aspirated
# 3         720S      McLaren  2021              212               V8 Twin-Turbo
